# %%
#Dhanwantari Chavan
# 711 
# G1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("sales_data_sample.csv")
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# ...

# %%
# 1. Identify Country wise Sales
newdf=df.groupby('COUNTRY')
country=df['COUNTRY'].unique()
sales=[]
for cname in country:
    sales.append(sum(newdf.get_group(cname)['SALES']))
    
f = plt.figure()
f.set_figwidth(30)
f.set_figheight(10)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.bar(country, sales, label="Country wise sales")
plt.legend(loc="best")

# %%
# 2. Identify the most common DEALSIZE
dsize=df['DEALSIZE'].unique()
deal=[]
newdf=df.groupby('DEALSIZE')
for dname in dsize:
    deal.append(newdf.get_group(dname)['DEALSIZE'].count())

plt.bar(df['DEALSIZE'].unique(),deal, label="DEALSIZE")
plt.legend(loc="best")

# %%
# 3. find precentage of status resolved, on hold, in Process, Disputed
newdf=df.groupby('STATUS')
tot=df['STATUS'].count()
status=df['STATUS'].unique()
percent=[]
for sname in status:
    percent.append(newdf.get_group(sname)['STATUS'].count()*100/tot)

# %%
plt.pie(percent, labels=status,autopct='%1.1f%%')
plt.title('Percentage of Status resolved, on hold, in Process, Disputed')
# Out:
# Text(0.5, 1.0, 'Percentage of Status resolved, on hold, in Process, Disputed')

# %%
size=df.groupby('DEALSIZE')
tot=df["DEALSIZE"].count()
status=df['DEALSIZE'].unique()

# %%
percent=[]
for sname in status:
    percent.append(size.get_group(sname)['DEALSIZE'].count()*100/tot)

# %%
plt.pie(percent,labels=status,autopct='%1.1f%%')
plt.title('Percentage of sizes of package')
# Out:
# Text(0.5, 1.0, 'Percentage of sizes of package')

# %%
import seaborn as sn

# %%
sn.catplot(data=df, x="PRODUCTLINE", y="YEAR_ID")

# %%
newdf=df.groupby('SALES')
status=df['MONTH_ID'].unique()
sales=[]
for dname in status:
   sales.append(newdf.get_group(dname)['SALES'].count())
status
# plt.plot(status, sales)  # Plot the chart
# plt.show()  # display
# Out:
# array([ 2,  5,  7,  8, 10, 11, 12,  1,  4,  6,  9,  3], dtype=int64)

# %%
newdf=df.groupby('MONTH_ID')
month=df['MONTH_ID'].unique()
sales=[]
for cname in month:
    sales.append(sum(newdf.get_group(cname)['SALES']))

# %%
sn.catplot(data=df, x="MONTH_ID", y="SALES", errorbar=("pi", 95), kind="bar")

# %%
newdf=df.groupby('PRODUCTLINE')
product=df['PRODUCTLINE'].unique()
sales=[]
for cname in product:
    sales.append(sum(newdf.get_group(cname)['SALES']))

# %%
f = plt.figure()
f.set_figwidth(30)
f.set_figheight(10)

font1 = {'family':'serif','color':'blue','size':10}
font2 = {'family':'serif','color':'darkred','size':15}
plt.bar(product,sales, label="Product wise sales")
plt.legend(loc="best")
